# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.model_selection import train_test_split
plt.rcParams["figure.figsize"] = (10,8)

import statsmodels.formula.api as smf


from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree



from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics


# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("TRAIN4.csv", index_col = 0)
df.head(2)
# Out:
#            cut color clarity  depth  table     x     y     z  price  \
# carat
# 0.30   Premium     D     SI2   62.4   58.0  4.31  4.28  2.68  6.353
# 1.01     Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04  9.183
#
#        cut_encoded  color_encoded  clarity_encoded
# carat
# 0.30             1              5                0
# 1.01             4              6                5

# %%
# Reparto de datos en train y test
# ==============================================================================
# Lo primero que hacemos es definir cuál es nuestra variable Y y nuestras variables X
X = df.drop(['price', 'cut', 'color', 'clarity'], axis=1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    29568.000000
# mean         7.702887
# std          0.976932
# min          5.787000
# 25%          6.809000
# 50%          7.694000
# 75%          8.505000
# max          9.842000
# Name: price, dtype: float64

# %%
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de testeo
# -----------------------
# count    7392.000000
# mean        7.702766
# std         0.985273
# min         5.817000
# 25%         6.801000
# 50%         7.689000
# 75%         8.513250
# max         9.842000
# Name: price, dtype: float64

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# %time
fig = plt.figure(figsize=(10, 6))
tree.plot_tree(regressor, feature_names=X_train.columns, filled=True)
plt.show();
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 3.1 µs

# %%
# max features

max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 2.8284271247461903

# %%
# max depth

print(regressor.tree_.max_depth)
# Out:
# 33

# %%
# hacemos las predicciones sobre los dos set de datos el X_test y el X_train
y_pred_test_dt = regressor.predict(X_test)
y_pred_train_dt = regressor.predict(X_train)

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    
    
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
# sacamos las métricas para ver si hay overfitting

dt_results1 = metricas(y_test, y_train, y_pred_test_dt, y_pred_train_dt, "Decission Tree I")
dt_results1
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.085523  0.014853  0.121875  0.984697   test  Decission Tree I
# 1  0.000224  0.000019  0.004390  0.999980  train  Decission Tree I

# %%
# Generación del GridSearch
# ==============================================================================

# definimos un diccionario con los hiperparámetros que queremos testear. 
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
# ajustamos el modelo de nuevo

# %time
gs.fit(X_train, y_train)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.267, test=-0.259) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.211, test=-0.208) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.080, test=-0.082) total time=   0.1s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.351, test=-0.357) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.363, test=-0.363) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.121, test=-0.124) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.421, test=-0.425) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.163, test=-0.163) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.288, test=-0.289) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.161, test=-0.163) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.145, test=-0.150) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.435, test=-0.431) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.335, test=-0.355) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.074, test=-0.077) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.078, test=-0.080) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.084, test=-0.087) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.176, test=-0.185) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.081, test=-0.081) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.374, test=-0.384) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.317, test=-0.329) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.170, test=-0.179) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.084, test=-0.086) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.387, test=-0.384) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.291, test=-0.305) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.185, test=-0.189) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.142, test=-0.144) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.078, test=-0.080) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.217, test=-0.215) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.360, test=-0.347) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.573, test=-0.597) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.117, test=-0.122) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.121, test=-0.124) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.055, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.117, test=-0.121) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.063, test=-0.066) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.066, test=-0.069) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.089, test=-0.086) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.065, test=-0.065) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.137, test=-0.139) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.063, test=-0.064) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.103, test=-0.100) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.085, test=-0.086) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.066, test=-0.066) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.083, test=-0.082) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.066, test=-0.069) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.232, test=-0.230) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.121, test=-0.122) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.087, test=-0.087) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.086, test=-0.087) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.570, test=-0.567) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.085, test=-0.084) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.096, test=-0.097) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.087, test=-0.089) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.164, test=-0.165) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.085, test=-0.084) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.220, test=-0.222) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.061, test=-0.063) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.081, test=-0.080) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.064, test=-0.066) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.060, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.062, test=-0.064) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.060, test=-0.063) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.056, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.052, test=-0.054) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.063, test=-0.064) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.059, test=-0.059) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.060, test=-0.062) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.060, test=-0.064) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.082, test=-0.083) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.089, test=-0.091) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.059, test=-0.064) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.075, test=-0.073) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.055, test=-0.054) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.054, test=-0.056) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.059, test=-0.062) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.076, test=-0.076) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.086, test=-0.086) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.060, test=-0.064) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.054, test=-0.057) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.052, test=-0.052) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.063, test=-0.065) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.084, test=-0.084) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.073, test=-0.074) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.059, test=-0.059) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.052, test=-0.052) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.056, test=-0.055) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.053, test=-0.055) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.060, test=-0.062) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.069, test=-0.070) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.051, test=-0.052) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.068, test=-0.067) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.053, test=-0.055) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.058, test=-0.059) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.052, test=-0.055) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.053, test=-0.055) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.054, test=-0.054) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.059, test=-0.062) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.051, test=-0.050) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.052, test=-0.053) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.052, test=-0.055) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.053, test=-0.054) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.058, test=-0.059) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.054, test=-0.053) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.051, test=-0.053) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.060) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.052, test=-0.053) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.068, test=-0.069) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.050, test=-0.054) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.058, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.053, test=-0.052) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.052, test=-0.056) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.053, test=-0.051) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.058, test=-0.059) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.070, test=-0.071) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.052, test=-0.052) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.052, test=-0.051) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.052, test=-0.054) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.052, test=-0.051) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.053, test=-0.052) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.050, test=-0.054) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.052, test=-0.053) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.050, test=-0.053) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.051, test=-0.049) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.050, test=-0.052) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.057, test=-0.059) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.051, test=-0.055) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.052, test=-0.052) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.052, test=-0.050) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.049, test=-0.052) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.052, test=-0.051) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.050, test=-0.050) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.058, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.051, test=-0.052) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.057, test=-0.062) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.057, test=-0.056) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.052, test=-0.052) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.049, test=-0.052) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.049, test=-0.051) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.050, test=-0.050) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.057, test=-0.060) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.051, test=-0.053) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.057, test=-0.061) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.057, test=-0.056) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.050, test=-0.048) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.050, test=-0.053) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.049, test=-0.051) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.061, test=-0.061) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.052, test=-0.055) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.058, test=-0.061) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.049, test=-0.051) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.052, test=-0.054) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.495, test=-0.490) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.102, test=-0.105) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.125, test=-0.127) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.324, test=-0.346) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.187, test=-0.183) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.112, test=-0.112) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.076, test=-0.086) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.177, test=-0.183) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.073, test=-0.072) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.101, test=-0.100) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.167, test=-0.172) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.125, test=-0.127) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.156, test=-0.157) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.272, test=-0.264) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.117, test=-0.111) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.175, test=-0.183) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.148, test=-0.154) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.070, test=-0.068) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.093, test=-0.097) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.088, test=-0.089) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.452, test=-0.460) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.122, test=-0.121) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.070, test=-0.072) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.356, test=-0.355) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.126, test=-0.131) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.089, test=-0.093) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.314, test=-0.311) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.197, test=-0.205) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.147, test=-0.150) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.055, test=-0.057) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.045, test=-0.045) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.054, test=-0.055) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.123, test=-0.126) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.075, test=-0.077) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.048, test=-0.048) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.059, test=-0.064) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.063, test=-0.063) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.066, test=-0.066) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.048, test=-0.048) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.060, test=-0.062) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.074, test=-0.077) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.058, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.101, test=-0.105) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.053, test=-0.056) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.085, test=-0.083) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.071, test=-0.074) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.047, test=-0.050) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.054, test=-0.054) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.064, test=-0.065) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.137, test=-0.142) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.066, test=-0.066) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.054, test=-0.055) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.048, test=-0.051) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.078, test=-0.077) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.056, test=-0.058) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.045, test=-0.044) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.059, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.039, test=-0.041) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.041, test=-0.041) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.054, test=-0.054) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.065, test=-0.066) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.042, test=-0.043) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.047, test=-0.046) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.046, test=-0.048) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.062, test=-0.062) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.054, test=-0.059) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.052, test=-0.053) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.046, test=-0.048) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.045, test=-0.047) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.064, test=-0.063) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.054, test=-0.058) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.048, test=-0.049) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.052, test=-0.051) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.056, test=-0.058) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.044, test=-0.046) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.055, test=-0.057) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.053, test=-0.055) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.044, test=-0.046) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.048, test=-0.052) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.040, test=-0.042) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.045, test=-0.045) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.047, test=-0.048) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.042, test=-0.044) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.042, test=-0.041) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.039, test=-0.039) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.040, test=-0.043) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.051, test=-0.052) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.041, test=-0.040) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.043, test=-0.047) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.044, test=-0.043) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.039, test=-0.042) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.047, test=-0.049) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.041, test=-0.040) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.041, test=-0.043) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.040, test=-0.039) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.044, test=-0.044) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.043, test=-0.046) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.040, test=-0.043) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.038, test=-0.037) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.039, test=-0.041) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.039, test=-0.038) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.041, test=-0.043) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.044, test=-0.044) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.040, test=-0.040) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.038, test=-0.041) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.041, test=-0.042) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.037, test=-0.039) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.045, test=-0.045) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.047, test=-0.047) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.037, test=-0.041) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.042, test=-0.043) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.039, test=-0.038) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.046, test=-0.050) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.039, test=-0.039) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.040, test=-0.040) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.046, test=-0.048) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.040, test=-0.040) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.038, test=-0.039) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.040, test=-0.044) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.037, test=-0.037) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.038, test=-0.041) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.037, test=-0.037) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.037, test=-0.038) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.038, test=-0.038) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.037, test=-0.038) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.037, test=-0.040) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.038, test=-0.039) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.037, test=-0.037) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.038, test=-0.039) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.037, test=-0.037) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.037, test=-0.040) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.037, test=-0.036) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.039, test=-0.039) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.039, test=-0.043) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.037, test=-0.038) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.038, test=-0.036) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.040, test=-0.042) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.038, test=-0.037) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.056, test=-0.059) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.081, test=-0.083) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.061, test=-0.067) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.147, test=-0.145) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.127, test=-0.126) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.149, test=-0.152) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.167, test=-0.169) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.180, test=-0.186) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.053, test=-0.053) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.102, test=-0.097) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.070, test=-0.074) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.170, test=-0.180) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.051, test=-0.053) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.076, test=-0.079) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.059, test=-0.062) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.058, test=-0.058) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.096, test=-0.102) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.107, test=-0.106) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.073, test=-0.072) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.212, test=-0.218) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.088, test=-0.092) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.277, test=-0.283) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.084, test=-0.086) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.263, test=-0.252) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.447, test=-0.451) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.117, test=-0.122) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.283, test=-0.305) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.325, test=-0.304) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.084, test=-0.079) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.059, test=-0.061) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.046, test=-0.048) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.068, test=-0.070) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.041, test=-0.043) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.064, test=-0.067) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.037, test=-0.039) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.053, test=-0.054) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.054, test=-0.055) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.084, test=-0.086) total time=   0.0s
# ...
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=50;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.036, test=-0.038) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.034, test=-0.034) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.043, test=-0.047) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.032, test=-0.035) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.041, test=-0.045) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.044, test=-0.044) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.041, test=-0.045) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.036, test=-0.037) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.037, test=-0.040) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.031, test=-0.032) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.040, test=-0.044) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.032, test=-0.034) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.033, test=-0.034) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.045, test=-0.049) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.031, test=-0.033) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.039, test=-0.041) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.034, test=-0.038) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.029, test=-0.029) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.038, test=-0.037) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.026, test=-0.027) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.032, test=-0.034) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.032, test=-0.034) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.028, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.031, test=-0.035) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.034, test=-0.037) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.032, test=-0.032) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.032, test=-0.032) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.026, test=-0.027) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.034, test=-0.035) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.032, test=-0.034) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.027, test=-0.030) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.027, test=-0.026) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.025, test=-0.028) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.025, test=-0.028) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.034, test=-0.035) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.028, test=-0.029) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.028, test=-0.029) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.033, test=-0.033) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.023, test=-0.024) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.023, test=-0.027) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.024, test=-0.024) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.023, test=-0.024) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.031, test=-0.031) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.025, test=-0.028) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.026, test=-0.026) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.024) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.022) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.023) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.022) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.021, test=-0.022) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.022, test=-0.023) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.023, test=-0.027) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.022, test=-0.023) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.022, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.021, test=-0.023) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.022, test=-0.023) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.021, test=-0.023) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.022, test=-0.023) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.023) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.023, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.023, test=-0.023) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.024) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.021, test=-0.022) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.025) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.022, test=-0.023) total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
# sacamos cual es el mejor de todos los que hemos testeado usando el método best_estimator_

best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=6, min_samples_split=10)

# %%
# volvamos a intentar visualizar el árbol a ver como se ve: 

fig = plt.figure(figsize=(12, 6))
tree.plot_tree(best_tree, feature_names=X_train.columns, filled=True);

# %%
 #guardamos la imagen 

fig.savefig("decision_tree.png", facecolor="white")

# %%
print(tree.export_text(best_tree, feature_names= list(X_train.columns)))
# Out:
# |--- y <= 5.58
# |   |--- y <= 4.92
# |   |   |--- x <= 4.62
# |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- x <= 4.39
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.12]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.24]
# |   |   |   |   |   |--- x >  4.39
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.25]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.38]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- x <= 4.24
# |   |   |   |   |   |   |--- y <= 4.17
# |   |   |   |   |   |   |   |--- value: [6.09]
# |   |   |   |   |   |   |--- y >  4.17
# |   |   |   |   |   |   |   |--- value: [6.27]
# |   |   |   |   |   |--- x >  4.24
# |   |   |   |   |   |   |--- x <= 4.40
# |   |   |   |   |   |   |   |--- value: [6.47]
# |   |   |   |   |   |   |--- x >  4.40
# |   |   |   |   |   |   |   |--- value: [6.59]
# |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |--- x <= 4.26
# |   |   |   |   |   |--- x <= 4.08
# |   |   |   |   |   |   |--- x <= 3.99
# |   |   |   |   |   |   |   |--- value: [6.24]
# |   |   |   |   |   |   |--- x >  3.99
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |--- x >  4.08
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.50]
# |   |   |   |   |--- x >  4.26
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.46]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- x <= 4.41
# |   |   |   |   |   |   |   |--- value: [6.75]
# |   |   |   |   |   |   |--- x >  4.41
# |   |   |   |   |   |   |   |--- value: [6.86]
# |   |   |--- x >  4.62
# |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |--- z <= 3.38
# |   |   |   |   |   |   |--- x <= 4.69
# |   |   |   |   |   |   |   |--- value: [6.50]
# |   |   |   |   |   |   |--- x >  4.69
# |   |   |   |   |   |   |   |--- value: [6.67]
# |   |   |   |   |   |--- z >  3.38
# |   |   |   |   |   |   |--- value: [8.72]
# |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- x <= 4.67
# |   |   |   |   |   |   |   |--- value: [6.66]
# |   |   |   |   |   |   |--- x >  4.67
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- x <= 4.70
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |   |   |   |--- x >  4.70
# |   |   |   |   |   |   |   |--- value: [6.97]
# |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |--- x <= 4.79
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |   |--- x >  4.79
# |   |   |   |   |   |   |   |--- value: [6.77]
# |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |--- z <= 2.90
# |   |   |   |   |   |   |   |--- value: [6.80]
# |   |   |   |   |   |   |--- z >  2.90
# |   |   |   |   |   |   |   |--- value: [6.86]
# |   |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.91]
# |   |   |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.02]
# |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [7.07]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [7.19]
# |   |--- y >  4.92
# |   |   |--- x <= 5.10
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- z <= 3.08
# |   |   |   |   |   |--- x <= 4.96
# |   |   |   |   |   |   |--- clarity_encoded <= 1.00
# |   |   |   |   |   |   |   |--- value: [6.56]
# |   |   |   |   |   |   |--- clarity_encoded >  1.00
# |   |   |   |   |   |   |   |--- value: [6.73]
# |   |   |   |   |   |--- x >  4.96
# |   |   |   |   |   |   |--- y <= 5.03
# |   |   |   |   |   |   |   |--- value: [6.83]
# |   |   |   |   |   |   |--- y >  5.03
# |   |   |   |   |   |   |   |--- value: [7.03]
# |   |   |   |   |--- z >  3.08
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- y <= 5.03
# |   |   |   |   |   |   |   |--- value: [6.89]
# |   |   |   |   |   |   |--- y >  5.03
# |   |   |   |   |   |   |   |--- value: [7.01]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [6.99]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [7.20]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |--- x <= 4.97
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.74]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.91]
# |   |   |   |   |   |--- x >  4.97
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.98]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.13]
# |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |--- z <= 3.06
# |   |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |   |--- value: [7.11]
# |   |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |   |--- value: [7.29]
# |   |   |   |   |   |--- z >  3.06
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [7.35]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.54]
# |   |   |--- x >  5.10
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |--- x <= 5.31
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.15]
# |   |   |   |   |   |--- x >  5.31
# |   |   |   |   |   |   |--- z <= 3.47
# |   |   |   |   |   |   |   |--- value: [7.24]
# |   |   |   |   |   |   |--- z >  3.47
# |   |   |   |   |   |   |   |--- value: [7.47]
# |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- x <= 5.46
# |   |   |   |   |   |   |   |--- value: [7.14]
# |   |   |   |   |   |   |--- x >  5.46
# |   |   |   |   |   |   |   |--- value: [7.45]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- x <= 5.32
# |   |   |   |   |   |   |   |--- value: [7.34]
# |   |   |   |   |   |   |--- x >  5.32
# |   |   |   |   |   |   |   |--- value: [7.52]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |--- x <= 5.34
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.23]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.47]
# |   |   |   |   |   |--- x >  5.34
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.39]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.61]
# |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.51]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.64]
# |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |   |--- value: [7.78]
# |   |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |   |--- value: [7.97]
# |--- y >  5.58
# |   |--- y <= 6.28
# |   |   |--- x <= 6.01
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- y <= 5.84
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [7.69]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.19]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.65]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.84]
# |   |   |   |   |--- y >  5.84
# |   |   |   |   |   |--- clarity_encoded <= 1.00
# |   |   |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [7.80]
# |   |   |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.90]
# |   |   |   |   |   |--- clarity_encoded >  1.00
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.81]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |--- y <= 5.64
# |   |   |   |   |   |   |   |--- value: [7.34]
# |   |   |   |   |   |   |--- y >  5.64
# |   |   |   |   |   |   |   |--- value: [7.63]
# |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |--- z <= 3.62
# |   |   |   |   |   |   |   |--- value: [7.83]
# |   |   |   |   |   |   |--- z >  3.62
# |   |   |   |   |   |   |   |--- value: [7.99]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- z <= 3.62
# |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |--- z >  3.62
# |   |   |   |   |   |   |   |--- value: [8.16]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [8.11]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [8.27]
# |   |   |--- x >  6.01
# |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |--- z <= 3.74
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- y <= 6.15
# |   |   |   |   |   |   |   |--- value: [7.87]
# |   |   |   |   |   |   |--- y >  6.15
# |   |   |   |   |   |   |   |--- value: [8.12]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- value: [7.56]
# |   |   |   |   |--- z >  3.74
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [8.09]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [8.21]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [7.60]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [7.80]
# |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |--- z <= 3.78
# |   |   |   |   |   |   |   |--- value: [7.75]
# |   |   |   |   |   |   |--- z >  3.78
# |   |   |   |   |   |   |   |--- value: [8.05]
# |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [8.11]
# |   |   |   |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [8.21]
# |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |--- y <= 6.14
# |   |   |   |   |   |   |--- z <= 3.77
# |   |   |   |   |   |   |   |--- value: [8.15]
# |   |   |   |   |   |   |--- z >  3.77
# |   |   |   |   |   |   |   |--- value: [8.32]
# |   |   |   |   |   |--- y >  6.14
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [8.40]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [8.74]
# |   |--- y >  6.28
# |   |   |--- x <= 7.09
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- y <= 6.76
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.37]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [8.05]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.38]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.54]
# |   |   |   |   |--- y >  6.76
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.59]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [8.23]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- y <= 6.92
# |   |   |   |   |   |   |   |--- value: [8.69]
# |   |   |   |   |   |   |--- y >  6.92
# |   |   |   |   |   |   |   |--- value: [8.81]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- y <= 6.69
# |   |   |   |   |   |   |--- y <= 6.42
# |   |   |   |   |   |   |   |--- value: [8.44]
# |   |   |   |   |   |   |--- y >  6.42
# |   |   |   |   |   |   |   |--- value: [8.58]
# |   |   |   |   |   |--- y >  6.69
# |   |   |   |   |   |   |--- y <= 6.88
# |   |   |   |   |   |   |   |--- value: [8.71]
# |   |   |   |   |   |   |--- y >  6.88
# |   |   |   |   |   |   |   |--- value: [8.82]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- y <= 6.73
# |   |   |   |   |   |   |   |--- value: [8.82]
# |   |   |   |   |   |   |--- y >  6.73
# |   |   |   |   |   |   |   |--- value: [9.11]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [9.09]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [9.30]
# |   |   |--- x >  7.09
# |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |--- y <= 7.62
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- y <= 7.19
# |   |   |   |   |   |   |   |--- value: [8.75]
# |   |   |   |   |   |   |--- y >  7.19
# |   |   |   |   |   |   |   |--- value: [9.03]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- z <= 4.66
# |   |   |   |   |   |   |   |--- value: [8.55]
# |   |   |   |   |   |   |--- z >  4.66
# |   |   |   |   |   |   |   |--- value: [8.72]
# |   |   |   |   |--- y >  7.62
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- y <= 7.86
# |   |   |   |   |   |   |   |--- value: [9.23]
# |   |   |   |   |   |   |--- y >  7.86
# |   |   |   |   |   |   |   |--- value: [9.52]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- y <= 8.11
# |   |   |   |   |   |   |   |--- value: [8.75]
# |   |   |   |   |   |   |--- y >  8.11
# |   |   |   |   |   |   |   |--- value: [9.27]
# |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- y <= 7.52
# |   |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.94]
# |   |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [9.17]
# |   |   |   |   |   |--- y >  7.52
# |   |   |   |   |   |   |--- z <= 4.84
# |   |   |   |   |   |   |   |--- value: [9.30]
# |   |   |   |   |   |   |--- z >  4.84
# |   |   |   |   |   |   |   |--- value: [9.57]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |--- y <= 7.49
# |   |   |   |   |   |   |   |--- value: [9.31]
# |   |   |   |   |   |   |--- y >  7.49
# |   |   |   |   |   |   |   |--- value: [9.51]
# |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |--- y <= 7.22
# |   |   |   |   |   |   |   |--- value: [9.38]
# |   |   |   |   |   |   |--- y >  7.22
# |   |   |   |   |   |   |   |--- value: [9.59]

# %%
y_pred_test_dt2 = best_tree.predict(X_test)
y_pred_train_dt2 = best_tree.predict(X_train)

# %%
dt_results2 = metricas(y_test, y_train, y_pred_test_dt2, y_pred_train_dt2, "Decision tree II")

# %%
dt_results2
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.117860  0.023101  0.151992  0.976200   test  Decision tree II
# 1  0.115693  0.022064  0.148540  0.976881  train  Decision tree II

# %% [markdown]
# # prueba predicciones

# %%
df = pd.read_csv("realidad3.csv", index_col = 0)
X_realida = df.drop(['cut', 'color', 'clarity'], axis=1)

# %%
X_realida_submision = best_tree.predict(X_realida)
X_realida_submision
# Out:
# array([6.24715217, 8.37584649, 9.50677966, ..., 6.46869077, 8.80995161,
#        8.00399057])

# %%
submision1 = pd.DataFrame(X_realida_submision)
submision1.reset_index(inplace=True)
submision1.rename(columns={"index":"id",0:"price"}, inplace =True)
submision1
# Out:
#           id     price
# 0          0  6.247152
# 1          1  8.375846
# 2          2  9.506780
# 3          3  7.897707
# 4          4  8.149173
# ...      ...       ...
# 12246  12246  8.544296
# 12247  12247  8.400821
# 12248  12248  6.468691
# 12249  12249  8.809952
# 12250  12250  8.003991
#
# [12251 rows x 2 columns]

# %%
submision1.to_csv("valen3.csv", index=False)
