# %%
import pandas as pd
import numpy as np

from tqdm import tqdm

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.model_selection import train_test_split
plt.rcParams["figure.figsize"] = (10,8)

import statsmodels.formula.api as smf


from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree



from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics


# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("realidad.csv", index_col = 0)
df.head(2)
# Out:
#            cut color clarity  depth  table     x     y     z  cut_encoded  \
# carat
# 0.32     Ideal     I     SI1   60.5   58.0  4.43  4.49  2.70            4
# 1.24   Premium     I     SI1   62.9   60.0  6.80  6.74  4.26            1
#
#        color_encoded  clarity_encoded
# carat
# 0.32               1                2
# 1.24               1                2

# %%
# Reparto de datos en train y test
# ==============================================================================
# Lo primero que hacemos es definir cuál es nuestra variable Y y nuestras variables X
X = df.drop([ 'cut', 'color', 'clarity'], axis=1)
X
# Out:
#        depth  table     x     y     z  cut_encoded  color_encoded  \
# carat
# 0.32    60.5   58.0  4.43  4.49  2.70            4              1
# 1.24    62.9   60.0  6.80  6.74  4.26            1              1
# 1.66    62.0   59.0  7.55  7.60  4.70            1              5
# 0.75    60.6   56.0  5.94  5.90  3.59            1              5
# 1.50    64.8   55.0  7.26  7.15  4.67            0              6
# ...      ...    ...   ...   ...   ...          ...            ...
# 1.10    59.6   60.0  6.74  6.70  4.00            1              3
# 0.90    62.1   60.0  6.14  6.20  3.83            3              5
# 0.30    62.1   53.3  4.30  4.32  2.68            4              4
# 1.25    59.6   59.0  7.01  7.09  4.20            4              1
# 0.81    61.6   58.0  5.96  5.92  3.66            1              4
#
#        clarity_encoded
# carat
# 0.32                 2
# 1.24                 2
# 1.66                 2
# 0.75                 0
# 1.50                 0
# ...                ...
# 1.10                 2
# 0.90                 2
# 0.30                 3
# 1.25                 2
# 0.81                 2
#
# [13485 rows x 8 columns]

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# %time
fig = plt.figure(figsize=(10, 6))
tree.plot_tree(regressor, feature_names=X_train.columns, filled=True)
plt.show();
# Out:
# CPU times: user 4 µs, sys: 2 µs, total: 6 µs
# Wall time: 13.8 µs

# %%
# max features

max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 2.8284271247461903

# %%
# max depth

print(regressor.tree_.max_depth)
# Out:
# 31

# %%
# hacemos las predicciones sobre los dos set de datos el X_test y el X_train
y_pred_test_dt = regressor.predict(X_test)
y_pred_train_dt = regressor.predict(X_train)

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    
    
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
# sacamos las métricas para ver si hay overfitting

dt_results1 = metricas(y_test, y_train, y_pred_test_dt, y_pred_train_dt, "Decission Tree I")
dt_results1
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.091860  0.018044  0.134328  0.982331   test  Decission Tree I
# 1  0.000224  0.000017  0.004178  0.999983  train  Decission Tree I

# %%
# Generación del GridSearch
# ==============================================================================

# definimos un diccionario con los hiperparámetros que queremos testear. 
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
# ajustamos el modelo de nuevo

# %time
gs.fit(X_train, y_train)
# Out:
# CPU times: user 8 µs, sys: 14 µs, total: 22 µs
# Wall time: 59.1 µs
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.260, test=-0.261) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.658, test=-0.659) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.126, test=-0.125) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.193, test=-0.194) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.683, test=-0.714) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.879, test=-0.886) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.260, test=-0.268) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.926, test=-0.932) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.184, test=-0.180) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.780, test=-0.774) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.362, test=-0.378) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.299, test=-0.296) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.079, test=-0.079) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.511, test=-0.528) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.124, test=-0.121) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.219, test=-0.221) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.078, test=-0.086) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.529, test=-0.528) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.159, test=-0.154) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.105, test=-0.113) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.102, test=-0.100) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.186, test=-0.185) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.291, test=-0.297) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.157, test=-0.166) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.320, test=-0.326) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.162, test=-0.163) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.648, test=-0.640) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.110, test=-0.110) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.528, test=-0.513) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.833, test=-0.828) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.078, test=-0.074) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.119, test=-0.122) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.171, test=-0.176) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.194, test=-0.199) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.078, test=-0.079) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.116, test=-0.114) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.092, test=-0.099) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.104, test=-0.103) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.087, test=-0.085) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.064, test=-0.069) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.071, test=-0.072) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.110, test=-0.108) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.298, test=-0.301) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.096, test=-0.101) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.074, test=-0.075) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.476, test=-0.460) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.086, test=-0.094) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.091, test=-0.096) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.068, test=-0.065) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.065, test=-0.069) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.122, test=-0.123) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.255, test=-0.253) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.106, test=-0.105) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.117, test=-0.118) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.122, test=-0.117) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.074, test=-0.077) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.130, test=-0.134) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.071, test=-0.073) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.115, test=-0.110) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.104, test=-0.108) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.106, test=-0.105) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.065, test=-0.065) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.064, test=-0.063) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.064, test=-0.066) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.063, test=-0.066) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.059, test=-0.059) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.090, test=-0.092) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.061, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.063, test=-0.063) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.058, test=-0.064) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.068, test=-0.066) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.061, test=-0.061) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.066, test=-0.066) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.062, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.066, test=-0.064) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.084, test=-0.086) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.062, test=-0.068) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.113, test=-0.110) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.060, test=-0.058) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.074, test=-0.079) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.064, test=-0.065) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.063, test=-0.062) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.063, test=-0.063) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.067, test=-0.066) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.058, test=-0.058) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.064, test=-0.063) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.070, test=-0.078) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.101, test=-0.094) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.069, test=-0.074) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.056, test=-0.057) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.063, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.062, test=-0.062) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.058, test=-0.059) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.058, test=-0.062) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.060, test=-0.060) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.058, test=-0.056) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=10;, score=(train=-0.060, test=-0.067) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.060, test=-0.059) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.058, test=-0.058) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.064, test=-0.063) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.063, test=-0.069) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.057, test=-0.056) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.062, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=50;, score=(train=-0.064, test=-0.070) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.062) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.065, test=-0.065) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.061) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.060, test=-0.059) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.068) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.075, test=-0.077) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.062, test=-0.060) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=4, min_samples_split=100;, score=(train=-0.061, test=-0.065) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.060, test=-0.058) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.060, test=-0.059) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.058, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.057, test=-0.063) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.058, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.064, test=-0.062) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=10;, score=(train=-0.059, test=-0.064) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.059, test=-0.059) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.056, test=-0.060) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.062, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=50;, score=(train=-0.057, test=-0.061) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.064, test=-0.062) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.063, test=-0.063) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.060, test=-0.060) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.060, test=-0.061) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.062, test=-0.064) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.066, test=-0.071) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.062, test=-0.059) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=5, min_samples_split=100;, score=(train=-0.062, test=-0.067) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.054, test=-0.054) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.060, test=-0.059) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.055, test=-0.058) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.055, test=-0.054) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.055, test=-0.053) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=10;, score=(train=-0.055, test=-0.061) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.060, test=-0.060) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.055, test=-0.056) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.057, test=-0.056) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.059, test=-0.063) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.056, test=-0.053) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.057, test=-0.055) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=50;, score=(train=-0.056, test=-0.062) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.057) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.056) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.057) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.060, test=-0.064) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.063, test=-0.064) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.055, test=-0.054) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=6, min_samples_split=100;, score=(train=-0.056, test=-0.062) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.113, test=-0.115) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.713, test=-0.713) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.214, test=-0.234) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.194, test=-0.205) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.202, test=-0.207) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.128, test=-0.125) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.235, test=-0.245) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.132, test=-0.138) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.144, test=-0.138) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=10;, score=(train=-0.125, test=-0.119) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.104, test=-0.104) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.154, test=-0.152) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.074, test=-0.075) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.076, test=-0.078) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.615, test=-0.618) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.067, test=-0.066) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.418, test=-0.431) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.394, test=-0.411) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.350, test=-0.341) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=50;, score=(train=-0.098, test=-0.103) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.239, test=-0.241) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.730, test=-0.734) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.133, test=-0.132) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.261, test=-0.272) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.082, test=-0.086) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.565, test=-0.566) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.421, test=-0.413) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.086, test=-0.087) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.139, test=-0.132) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=1, min_samples_split=100;, score=(train=-0.144, test=-0.151) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.085, test=-0.085) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.058, test=-0.057) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.103, test=-0.104) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.156, test=-0.151) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.064, test=-0.065) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.053, test=-0.059) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=10;, score=(train=-0.054, test=-0.061) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.078, test=-0.077) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.145, test=-0.146) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.055, test=-0.055) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.050, test=-0.052) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.075, test=-0.079) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.058, test=-0.062) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.077, test=-0.080) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.072, test=-0.072) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=50;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.074, test=-0.073) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.082, test=-0.078) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.070, test=-0.071) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.062, test=-0.063) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.063, test=-0.064) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.094, test=-0.101) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.092, test=-0.093) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=2, min_samples_split=100;, score=(train=-0.053, test=-0.059) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.067, test=-0.067) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.063, test=-0.066) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.054, test=-0.052) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.054, test=-0.053) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.047, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.055, test=-0.062) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.047, test=-0.047) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.048, test=-0.047) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=10;, score=(train=-0.046, test=-0.049) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.053, test=-0.052) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.056, test=-0.059) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.056, test=-0.055) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.047, test=-0.050) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.049, test=-0.050) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.053, test=-0.057) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.052, test=-0.054) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.057, test=-0.057) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=50;, score=(train=-0.052, test=-0.059) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.047, test=-0.048) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.049, test=-0.050) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.055, test=-0.054) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.049, test=-0.051) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.060, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.049, test=-0.047) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.052, test=-0.057) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.053, test=-0.055) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.104, test=-0.099) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=3, min_samples_split=100;, score=(train=-0.058, test=-0.062) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.045, test=-0.045) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.052, test=-0.051) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.047, test=-0.047) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.044, test=-0.046) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.046, test=-0.044) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.048, test=-0.050) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.044, test=-0.047) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.045, test=-0.044) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=10;, score=(train=-0.044, test=-0.048) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.061, test=-0.059) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.051, test=-0.053) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.047, test=-0.047) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.053, test=-0.050) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.047, test=-0.046) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.046, test=-0.047) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.045, test=-0.049) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.048, test=-0.048) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.045, test=-0.043) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=50;, score=(train=-0.046, test=-0.052) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.047, test=-0.046) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.051, test=-0.052) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.051, test=-0.050) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.048, test=-0.049) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.051, test=-0.051) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.053, test=-0.056) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.050, test=-0.051) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.047, test=-0.046) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=4, min_samples_split=100;, score=(train=-0.055, test=-0.062) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.046, test=-0.047) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.044, test=-0.046) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.045, test=-0.044) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.044, test=-0.044) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=10;, score=(train=-0.046, test=-0.052) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.046, test=-0.045) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.046, test=-0.046) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.051, test=-0.054) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.048, test=-0.047) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=50;, score=(train=-0.047, test=-0.053) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.044, test=-0.046) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.050, test=-0.049) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.045, test=-0.047) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.049, test=-0.049) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.053, test=-0.051) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.046, test=-0.048) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.044, test=-0.043) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=5, min_samples_split=100;, score=(train=-0.042, test=-0.046) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.042, test=-0.044) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.042, test=-0.043) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.044, test=-0.043) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.045, test=-0.042) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=10;, score=(train=-0.043, test=-0.048) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.040, test=-0.042) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.044, test=-0.044) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.042, test=-0.043) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.043, test=-0.041) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=50;, score=(train=-0.044, test=-0.050) total time=   0.0s
# [CV 1/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 2/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.044) total time=   0.0s
# [CV 3/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 4/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.046) total time=   0.0s
# [CV 5/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.049, test=-0.047) total time=   0.0s
# [CV 6/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.042, test=-0.042) total time=   0.0s
# [CV 7/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.048, test=-0.053) total time=   0.0s
# [CV 8/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.043) total time=   0.0s
# [CV 9/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.042) total time=   0.0s
# [CV 10/10] END max_depth=5, max_features=6, min_samples_split=100;, score=(train=-0.043, test=-0.048) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.089, test=-0.091) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.060, test=-0.061) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.100, test=-0.104) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.153, test=-0.162) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.143, test=-0.143) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.062, test=-0.064) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.130, test=-0.136) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.176, test=-0.177) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.117, test=-0.117) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=10;, score=(train=-0.073, test=-0.077) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.054, test=-0.055) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.174, test=-0.178) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.103, test=-0.102) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.081, test=-0.081) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.072, test=-0.071) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.101, test=-0.112) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.060, test=-0.062) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.223, test=-0.221) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=50;, score=(train=-0.091, test=-0.096) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.135, test=-0.129) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.095, test=-0.094) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.084, test=-0.084) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.079, test=-0.080) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.111, test=-0.104) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.589, test=-0.619) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.163, test=-0.170) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.250, test=-0.256) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.127, test=-0.125) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=1, min_samples_split=100;, score=(train=-0.525, test=-0.535) total time=   0.0s
# [CV 1/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.086, test=-0.086) total time=   0.0s
# [CV 2/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 3/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.054, test=-0.057) total time=   0.0s
# [CV 4/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.066, test=-0.065) total time=   0.0s
# [CV 5/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.072, test=-0.074) total time=   0.0s
# [CV 6/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 7/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.044, test=-0.049) total time=   0.0s
# [CV 8/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.045, test=-0.046) total time=   0.0s
# [CV 9/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.053, test=-0.050) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.277, test=-0.269) total time=   0.0s
# ...
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=50;, score=(train=-0.037, test=-0.045) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.048, test=-0.049) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.042, test=-0.044) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.044, test=-0.045) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.068, test=-0.070) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.081, test=-0.083) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.050, test=-0.050) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.043, test=-0.045) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.041, test=-0.044) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.042, test=-0.044) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.042, test=-0.047) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.034, test=-0.035) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.030, test=-0.030) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.033, test=-0.033) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.038, test=-0.039) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.035, test=-0.037) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.038, test=-0.043) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.036, test=-0.038) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.034, test=-0.034) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.033, test=-0.036) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.038, test=-0.041) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.031, test=-0.030) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.033, test=-0.033) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.039, test=-0.040) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.039, test=-0.043) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.041, test=-0.047) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.037, test=-0.042) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.035, test=-0.036) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.031, test=-0.031) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.031, test=-0.032) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.033, test=-0.036) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.031, test=-0.034) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.038, test=-0.038) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.047, test=-0.055) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.035, test=-0.037) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.031, test=-0.034) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.029, test=-0.029) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.027, test=-0.033) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.030, test=-0.029) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.031, test=-0.031) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.027, test=-0.027) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.028, test=-0.032) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.031, test=-0.032) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.036) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.029, test=-0.029) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.026, test=-0.026) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.029, test=-0.032) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.033, test=-0.036) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.028, test=-0.032) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.027, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.025, test=-0.029) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.031) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.027, test=-0.030) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.027) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.027, test=-0.034) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.027, test=-0.031) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.026, test=-0.029) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.026, test=-0.026) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.023, test=-0.024) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.029) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.027) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.023, test=-0.024) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.026, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.027, test=-0.031) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.026, test=-0.026) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.027, test=-0.030) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.026) total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
# sacamos cual es el mejor de todos los que hemos testeado usando el método best_estimator_

best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=6, min_samples_split=50)

# %%
# volvamos a intentar visualizar el árbol a ver como se ve: 

fig = plt.figure(figsize=(12, 6))
tree.plot_tree(best_tree, feature_names=X_train.columns, filled=True);

# %%
 #guardamos la imagen 

fig.savefig("decision_tree.png", facecolor="white")

# %%
print(tree.export_text(best_tree, feature_names= list(X_train.columns)))
# Out:
# |--- y <= 5.61
# |   |--- x <= 4.92
# |   |   |--- y <= 4.60
# |   |   |   |--- x <= 4.30
# |   |   |   |   |--- z <= 1.13
# |   |   |   |   |   |--- value: [9.37]
# |   |   |   |   |--- z >  1.13
# |   |   |   |   |   |--- x <= 4.10
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.07]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.29]
# |   |   |   |   |   |--- x >  4.10
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.28]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.53]
# |   |   |   |--- x >  4.30
# |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.20]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.39]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.46]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.65]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- x <= 4.42
# |   |   |   |   |   |   |   |--- value: [6.77]
# |   |   |   |   |   |   |--- x >  4.42
# |   |   |   |   |   |   |   |--- value: [6.87]
# |   |   |--- y >  4.60
# |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- x <= 4.68
# |   |   |   |   |   |   |--- x <= 4.62
# |   |   |   |   |   |   |   |--- value: [6.31]
# |   |   |   |   |   |   |--- x >  4.62
# |   |   |   |   |   |   |   |--- value: [6.47]
# |   |   |   |   |   |--- x >  4.68
# |   |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [6.50]
# |   |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [6.65]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- x <= 4.70
# |   |   |   |   |   |   |   |--- value: [6.42]
# |   |   |   |   |   |   |--- x >  4.70
# |   |   |   |   |   |   |   |--- value: [6.61]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- x <= 4.76
# |   |   |   |   |   |   |   |--- value: [6.70]
# |   |   |   |   |   |   |--- x >  4.76
# |   |   |   |   |   |   |   |--- value: [6.82]
# |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |--- x <= 4.67
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.47]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |--- x >  4.67
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.83]
# |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |--- x <= 4.68
# |   |   |   |   |   |   |   |--- value: [6.82]
# |   |   |   |   |   |   |--- x >  4.68
# |   |   |   |   |   |   |   |--- value: [6.97]
# |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [7.03]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [7.17]
# |   |--- x >  4.92
# |   |   |--- y <= 5.24
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |--- x <= 5.06
# |   |   |   |   |   |   |--- z <= 3.11
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |   |   |   |--- z >  3.11
# |   |   |   |   |   |   |   |--- value: [6.96]
# |   |   |   |   |   |--- x >  5.06
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.98]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.11]
# |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- y <= 5.03
# |   |   |   |   |   |   |   |--- value: [6.84]
# |   |   |   |   |   |   |--- y >  5.03
# |   |   |   |   |   |   |   |--- value: [7.08]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- y <= 5.03
# |   |   |   |   |   |   |   |--- value: [7.05]
# |   |   |   |   |   |   |--- y >  5.03
# |   |   |   |   |   |   |   |--- value: [7.31]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- y <= 5.04
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- value: [6.92]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- z <= 3.03
# |   |   |   |   |   |   |   |--- value: [7.09]
# |   |   |   |   |   |   |--- z >  3.03
# |   |   |   |   |   |   |   |--- value: [7.32]
# |   |   |   |   |--- y >  5.04
# |   |   |   |   |   |--- z <= 3.07
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [7.23]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.47]
# |   |   |   |   |   |--- z >  3.07
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [7.41]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.62]
# |   |   |--- y >  5.24
# |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |--- y <= 5.51
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [7.04]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [7.20]
# |   |   |   |   |   |--- y >  5.51
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [7.51]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.03]
# |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |--- x <= 5.48
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.18]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.45]
# |   |   |   |   |   |--- x >  5.48
# |   |   |   |   |   |   |--- z <= 3.46
# |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |--- z >  3.46
# |   |   |   |   |   |   |   |--- value: [7.72]
# |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- x <= 5.48
# |   |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |   |--- value: [7.38]
# |   |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |   |--- value: [7.52]
# |   |   |   |   |   |--- x >  5.48
# |   |   |   |   |   |   |--- value: [7.62]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- x <= 5.48
# |   |   |   |   |   |   |   |--- value: [7.58]
# |   |   |   |   |   |   |--- x >  5.48
# |   |   |   |   |   |   |   |--- value: [7.83]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- y <= 5.40
# |   |   |   |   |   |   |   |--- value: [7.77]
# |   |   |   |   |   |   |--- y >  5.40
# |   |   |   |   |   |   |   |--- value: [7.96]
# |--- y >  5.61
# |   |--- y <= 6.76
# |   |   |--- y <= 6.12
# |   |   |   |--- y <= 5.93
# |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- y <= 5.87
# |   |   |   |   |   |   |   |--- value: [7.62]
# |   |   |   |   |   |   |--- y >  5.87
# |   |   |   |   |   |   |   |--- value: [7.78]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.73]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.86]
# |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [7.60]
# |   |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.85]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [8.20]
# |   |   |   |--- y >  5.93
# |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- depth <= 61.25
# |   |   |   |   |   |   |   |--- value: [7.84]
# |   |   |   |   |   |   |--- depth >  61.25
# |   |   |   |   |   |   |   |--- value: [8.02]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- value: [7.57]
# |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- z <= 3.75
# |   |   |   |   |   |   |   |--- value: [7.84]
# |   |   |   |   |   |   |--- z >  3.75
# |   |   |   |   |   |   |   |--- value: [8.05]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- y <= 6.07
# |   |   |   |   |   |   |   |--- value: [8.16]
# |   |   |   |   |   |   |--- y >  6.07
# |   |   |   |   |   |   |   |--- value: [8.30]
# |   |   |--- y >  6.12
# |   |   |   |--- y <= 6.35
# |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.22]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.80]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.08]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.38]
# |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.20]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.38]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- z <= 3.95
# |   |   |   |   |   |   |   |--- value: [8.51]
# |   |   |   |   |   |   |--- z >  3.95
# |   |   |   |   |   |   |   |--- value: [8.79]
# |   |   |   |--- y >  6.35
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.32]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.97]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.43]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.57]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.38]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.57]
# |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [8.89]
# |   |   |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [9.04]
# |   |--- y >  6.76
# |   |   |--- y <= 7.24
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- y <= 7.08
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.59]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [8.28]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.58]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.80]
# |   |   |   |   |--- y >  7.08
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- y <= 7.19
# |   |   |   |   |   |   |   |--- value: [8.75]
# |   |   |   |   |   |   |--- y >  7.19
# |   |   |   |   |   |   |   |--- value: [8.90]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [8.92]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [9.19]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- y <= 7.05
# |   |   |   |   |   |   |   |--- value: [8.67]
# |   |   |   |   |   |   |--- y >  7.05
# |   |   |   |   |   |   |   |--- value: [8.90]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- y <= 7.03
# |   |   |   |   |   |   |   |--- value: [8.89]
# |   |   |   |   |   |   |--- y >  7.03
# |   |   |   |   |   |   |   |--- value: [9.07]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- z <= 4.43
# |   |   |   |   |   |   |   |--- value: [9.11]
# |   |   |   |   |   |   |--- z >  4.43
# |   |   |   |   |   |   |   |--- value: [9.42]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [9.25]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [9.47]
# |   |   |--- y >  7.24
# |   |   |   |--- y <= 7.92
# |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- x <= 7.66
# |   |   |   |   |   |   |   |--- value: [9.03]
# |   |   |   |   |   |   |--- x >  7.66
# |   |   |   |   |   |   |   |--- value: [9.27]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- z <= 4.57
# |   |   |   |   |   |   |   |--- value: [8.51]
# |   |   |   |   |   |   |--- z >  4.57
# |   |   |   |   |   |   |   |--- value: [8.76]
# |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- y <= 7.63
# |   |   |   |   |   |   |   |--- value: [9.18]
# |   |   |   |   |   |   |--- y >  7.63
# |   |   |   |   |   |   |   |--- value: [9.39]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [9.38]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [9.59]
# |   |   |   |--- y >  7.92
# |   |   |   |   |--- x <= 6.50
# |   |   |   |   |   |--- value: [7.64]
# |   |   |   |   |--- x >  6.50
# |   |   |   |   |   |--- cut_encoded <= 0.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [9.60]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [9.22]
# |   |   |   |   |   |--- cut_encoded >  0.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [9.57]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [9.66]

# %%
y_pred_test_dt2 = best_tree.predict(X_test)
y_pred_train_dt2 = best_tree.predict(X_train)

# %%
dt_results2 = metricas(y_test, y_train, y_pred_test_dt2, y_pred_train_dt2, "Decision tree II")

# %%
dt_results2
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.123607  0.026071  0.161464  0.974472   test  Decision tree II
# 1  0.122053  0.024833  0.157586  0.976054  train  Decision tree II
